# %%
import sys
import os

if os.path.abspath('..') not in sys.path:
    sys.path.append(os.path.abspath('..'))

from src.mcp.openbb_client import get_current_stock_price

# Apple'ın (AAPL) güncel hisse fiyatını çekelim
sonuc = get_current_stock_price.invoke({"ticker": "AAPL"})
print(sonuc)
# Out:
# 📈 Piyasa Verisi Çekiliyor: AAPL...
# AAPL güncel hisse fiyatı: $314.37
