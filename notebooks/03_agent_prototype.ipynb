# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
from dotenv import load_dotenv

if os.path.abspath('..') not in sys.path:
    sys.path.append(os.path.abspath('..'))
    
load_dotenv()
# Out:
# True

# %%
from src.agents.graph import create_agent_graph

print("--- SİSTEM BAŞLATILIYOR ---")
app = create_agent_graph()

soru = "What is the common stock par value for Apple in the provided 10-K report, and what is the current stock price of AAPL today?"
print(f"\nSoru: {soru}\n")

print("--- AJANLAR ÇALIŞIYOR ---")
sonuc = app.invoke({"question": soru})

print("\n--- NİHAİ CEVAP ---")
print(sonuc["final_answer"])
# Out:
# --- SİSTEM BAŞLATILIYOR ---
#
# Soru: What is the common stock par value for Apple in the provided 10-K report, and what is the current stock price of AAPL today?
#
# --- AJANLAR ÇALIŞIYOR ---
# 🧠 Planner: Soru analiz ediliyor ve plan çıkarılıyor...
# 📚 Retriever: Qdrant veritabanında aranıyor...
# 🌐 Web Researcher: Hangi aracı kullanması gerektiğine karar veriyor ve araştırıyor...
# 📈 Piyasa Verisi Çekiliyor: AAPL...
# ✍️ Synthesizer: Veriler birleştiriliyor (Deneme: 1)...
# 🕵️‍♂️ Validator: Rakamlar ve kaynaklar kontrol ediliyor...
# ✅ Validator: Tüm sayılar doğru, onaylandı!
#
# --- NİHAİ CEVAP ---
# According to the latest 10-K report, Apple's common stock has a par value of $0.00001 per share. As of today, the current stock price of AAPL is $314.38.
